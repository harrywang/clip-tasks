# %%
from PIL import Image
import numpy as np
import pandas as pd
from transformers import CLIPProcessor, CLIPModel, CLIPImageProcessor

# %%
# one image using huggingface model https://huggingface.co/openai/clip-vit-large-patch14

model = CLIPModel.from_pretrained("openai/clip-vit-large-patch14")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-large-patch14")

# prepare images
#one_img = './1k-compressed/-bDYrrVAZnc.jpg'  # night
#one_img = './1k-compressed/-fjrjyS18BQ.jpg'  # dusk
im = './1k-compressed/-N_UwPdUs7E.jpg'  # dawn
#one_img = './1k-compressed/7kCNXfo35aU.jpg'  # day
#one_img = './1k-compressed/4_Bc9CSm70A.jpg'  # dusk or dawn

image = Image.open(im)

# prepare text prompts
labels = ['dawn', 'day', 'dusk', 'night']  # the target labels
text_prompts = ['An image taken at ' + label for label in labels]
print(text_prompts)

inputs = processor(text=text_prompts, images=image, return_tensors="pt", padding=True)

outputs = model(**inputs)
logits_per_image = outputs.logits_per_image # this is the image-text similarity score
probs = logits_per_image.softmax(dim=1) # we can take the softmax to get the label probabilities

choices = np.argmax(probs.detach().numpy())  # use argmax to get the largest number as the prediction
print(f'This image is classified as taken at {labels[choices]}')
# Out:
# ['An image taken at dawn', 'An image taken at day', 'An image taken at dusk', 'An image taken at night']
# This image is classified as taken at dawn

# %%
# 10 images using huggingface model https://huggingface.co/openai/clip-vit-large-patch14

# classify 1k-compressed images
photos = pd.read_csv('photos-1k.csv')

images = [Image.open(f'./1k-compressed/{img_id}.jpg') for img_id in photos['photo_id'][:10]]  # process images in batch

# prepare text prompts
labels = ['dawn', 'day', 'dusk', 'night']  # the target labels
text_prompts = ['An image taken at ' + label for label in labels]
print(text_prompts)

inputs = processor(text=text_prompts, images=images, return_tensors="pt", padding=True)

outputs = model(**inputs)
logits_per_image = outputs.logits_per_image # this is the image-text similarity score
probs = logits_per_image.softmax(dim=1) # we can take the softmax to get the label probabilities
# Out:
# ['An image taken at dawn', 'An image taken at day', 'An image taken at dusk', 'An image taken at night']

# %%
# build a df based on the result
df = pd.DataFrame(probs.detach().numpy(), columns=text_prompts)

# show the result - darker colored cell is the prediction
df.style.background_gradient(axis=None, low=0, high=0.91).format(precision=2)
# Out:
# <style type="text/css">
# #T_41424_row0_col0 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_41424_row0_col1 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_41424_row0_col2 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_41424_row0_col3 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_41424_row1_col0 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_41424_row1_col1 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_41424_row1_col2 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_41424_row1_col3, #T_41424_row6_col1, #T_41424_row6_col3, #T_41424_row7_col1, #T_41424_row8_col3 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_41424_row2_col0 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_41424_row2_col1 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_41424_row2_col2, #T_41424_row3_col2 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_41424_row2_col3 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_41424_row3_col0, #T_41424_row5_col0 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_41424_row3_col1, #T_41424_row8_col2 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_41424_row3_col3, #T_41424_row5_col3, #T_41424_row7_col3, #T_41424_row9_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_41424_row4_col0 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_41424_row4_col1 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_41424_row4_col2 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_41424_row4_col3 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_41424_row5_col1 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_41424_row5_col2 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_41424_row6_col0 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_41424_row6_col2 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_41424_row7_col0 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_41424_row7_col2, #T_41424_row8_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_41424_row8_col0 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_41424_row9_col0 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_41424_row9_col1 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_41424_row9_col2 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# </style>
# <table id="T_41424">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41424_level0_col0" class="col_heading level0 col0" >An image taken at dawn</th>
#       <th id="T_41424_level0_col1" class="col_heading level0 col1" >An image taken at day</th>
#       <th id="T_41424_level0_col2" class="col_heading level0 col2" >An image taken at dusk</th>
#       <th id="T_41424_level0_col3" class="col_heading level0 col3" >An image taken at night</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41424_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_41424_row0_col0" class="data row0 col0" >0.21</td>
#       <td id="T_41424_row0_col1" class="data row0 col1" >0.54</td>
#       <td id="T_41424_row0_col2" class="data row0 col2" >0.24</td>
#       <td id="T_41424_row0_col3" class="data row0 col3" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_41424_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_41424_row1_col0" class="data row1 col0" >0.28</td>
#       <td id="T_41424_row1_col1" class="data row1 col1" >0.57</td>
#       <td id="T_41424_row1_col2" class="data row1 col2" >0.12</td>
#       <td id="T_41424_row1_col3" class="data row1 col3" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_41424_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_41424_row2_col0" class="data row2 col0" >0.51</td>
#       <td id="T_41424_row2_col1" class="data row2 col1" >0.37</td>
#       <td id="T_41424_row2_col2" class="data row2 col2" >0.09</td>
#       <td id="T_41424_row2_col3" class="data row2 col3" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_41424_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_41424_row3_col0" class="data row3 col0" >0.46</td>
#       <td id="T_41424_row3_col1" class="data row3 col1" >0.44</td>
#       <td id="T_41424_row3_col2" class="data row3 col2" >0.10</td>
#       <td id="T_41424_row3_col3" class="data row3 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_41424_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_41424_row4_col0" class="data row4 col0" >0.36</td>
#       <td id="T_41424_row4_col1" class="data row4 col1" >0.10</td>
#       <td id="T_41424_row4_col2" class="data row4 col2" >0.48</td>
#       <td id="T_41424_row4_col3" class="data row4 col3" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_41424_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_41424_row5_col0" class="data row5 col0" >0.47</td>
#       <td id="T_41424_row5_col1" class="data row5 col1" >0.32</td>
#       <td id="T_41424_row5_col2" class="data row5 col2" >0.21</td>
#       <td id="T_41424_row5_col3" class="data row5 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_41424_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_41424_row6_col0" class="data row6 col0" >0.56</td>
#       <td id="T_41424_row6_col1" class="data row6 col1" >0.03</td>
#       <td id="T_41424_row6_col2" class="data row6 col2" >0.39</td>
#       <td id="T_41424_row6_col3" class="data row6 col3" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_41424_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_41424_row7_col0" class="data row7 col0" >0.81</td>
#       <td id="T_41424_row7_col1" class="data row7 col1" >0.02</td>
#       <td id="T_41424_row7_col2" class="data row7 col2" >0.16</td>
#       <td id="T_41424_row7_col3" class="data row7 col3" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_41424_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_41424_row8_col0" class="data row8 col0" >0.38</td>
#       <td id="T_41424_row8_col1" class="data row8 col1" >0.16</td>
#       <td id="T_41424_row8_col2" class="data row8 col2" >0.44</td>
#       <td id="T_41424_row8_col3" class="data row8 col3" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_41424_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_41424_row9_col0" class="data row9 col0" >0.48</td>
#       <td id="T_41424_row9_col1" class="data row9 col1" >0.09</td>
#       <td id="T_41424_row9_col2" class="data row9 col2" >0.43</td>
#       <td id="T_41424_row9_col3" class="data row9 col3" >0.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
choices = np.argmax(probs.detach().numpy(), axis=1)  # choose the largest prob
get_labels = np.vectorize(lambda x:labels[x])  # vectorized lambda function to get labels
predictions = get_labels(choices)  # an array
predictions
# Out:
# array(['day', 'day', 'dawn', 'dawn', 'dusk', 'dawn', 'dawn', 'dawn',
#        'dusk', 'dawn'], dtype='<U4')
